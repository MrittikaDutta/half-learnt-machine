# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#      crop  moisture  temp  pump
# 0  cotton       638    16     1
# 1  cotton       522    18     1
# 2  cotton       741    22     1
# 3  cotton       798    32     1
# 4  cotton       690    28     1

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(x='moisture',y='temp',data=df,hue='crop',s=120,alpha=0.6,style='pump')
#plt.savefig("mtplot.jpg")
# Out:
# <Axes: xlabel='moisture', ylabel='temp'>
